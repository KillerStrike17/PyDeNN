# %%
from DeNN.model import resnet
from DeNN.dataset_loader import data_loader, data_augmentation
from DeNN.trainer import trainer

# %%
import torch,torchvision
from torchsummary import summary
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision.transforms.functional import normalize, resize, to_tensor, to_pil_image

# %%
DATA_PATH = 'D:/Github/Dataset/'
BATCH_SIZE =128

# %%
my_transformations = data_augmentation.DataAugmentationCifar10_album()
train, test = data_loader.DatasetCifar10(data_path = DATA_PATH,transformations = my_transformations,batch_size = BATCH_SIZE).load_data()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = resnet.ResNet18().to(device)

# %%
summary(model,input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
trainer = trainer.Trainer( model =model , optimizer =optimizer , device =device , train_loader = train, test_loader = test,epochs = 5,criteria = criterion)

# %%
(w,x),(y,z) = trainer.train()
# Out:
# loss=1.2250468730926514 batch_id=390 Accuracy = 0.41042: 100%|███████████████████████| 391/391 [00:37<00:00, 10.56it/s]
# loss=1.4493112564086914 batch_id=0 Accuracy = 0.00134:   0%|                           | 1/391 [00:00<00:44,  8.80it/s]
# Test set: Average loss: 0.0104, Accuracy: 5248/10000 (52.48%)
# loss=1.068207025527954 batch_id=390 Accuracy = 0.56144: 100%|████████████████████████| 391/391 [00:37<00:00, 10.29it/s]
# loss=1.1161328554153442 batch_id=1 Accuracy = 0.00302:   0%|                           | 1/391 [00:00<00:39,  9.93it/s]
# Test set: Average loss: 0.0082, Accuracy: 6273/10000 (62.73%)
# loss=0.9902713894844055 batch_id=390 Accuracy = 0.63208: 100%|███████████████████████| 391/391 [00:37<00:00, 10.55it/s]
# loss=0.9833160042762756 batch_id=0 Accuracy = 0.00166:   0%|                           | 1/391 [00:00<00:39,  9.93it/s]
# Test set: Average loss: 0.0074, Accuracy: 6716/10000 (67.16%)
# loss=0.974729061126709 batch_id=390 Accuracy = 0.68118: 100%|████████████████████████| 391/391 [00:37<00:00, 10.55it/s]
# loss=0.9022113680839539 batch_id=0 Accuracy = 0.00176:   0%|                                   | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0066, Accuracy: 7060/10000 (70.60%)
# loss=0.729029655456543 batch_id=390 Accuracy = 0.71616: 100%|████████████████████████| 391/391 [00:37<00:00, 10.54it/s]
# Test set: Average loss: 0.0057, Accuracy: 7415/10000 (74.15%)

# %%
torch.save(model, 'D:\Github\EVA-5\Saved Models\model1')

# %%
from DeNN.visualization import *
from PIL import Image
from matplotlib.pyplot import imshow

# %%
model.eval()
# Out:
# Base Model Function

# %%
model
# Out:
# Base Model Function

# %%
image = Image.open('D:/Github/PyDeNN/DeNN/Tutorial/CAMs Visualization/car.jpg')
# image = Image.open('./sample/dogsled.jpg')
imshow(image)

# %%
normalize = transforms.Normalize(
   mean=[0.4914, 0.4822, 0.4465],
   std=[0.2023, 0.1994, 0.2010]
)

preprocess = transforms.Compose([
    transforms.ToTensor(),
    normalize
])
